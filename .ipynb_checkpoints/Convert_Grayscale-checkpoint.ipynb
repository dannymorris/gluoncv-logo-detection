# %% [markdown]
# # Raw Images to Grayscale
#
# This notebook converts raw images in S3 to grayscale versions and loads them to a different folder in the bucket.

# %%
import cv2
import numpy as np
import boto3

s3_client = boto3.client('s3')
response = s3_client.list_objects(Bucket='bcbs-logo-training-images', Prefix='raw_images')    
contents=response['Contents']
def get_key(d):
    return d['Key']    
keys = list(map(get_key, contents))[1:]

print("Number of raw images: {}".format(len(gray_keys)))
# Out:
# Number of raw images: 389

# %%
def convert_to_gray(s3_key):
    # defining s3 bucket object
    s3 = boto3.client("s3")
    bucket_name = "bcbs-logo-training-images"
    # fetching object from bucket
    file_obj = s3.get_object(Bucket=bucket_name, Key=s3_key)
    # reading the file content in bytes
    file_content = file_obj["Body"].read()
    # creating 1D array from bytes data range between[0,255]
    np_array = np.fromstring(file_content, np.uint8)
    # decoding array
    image_np = cv2.imdecode(np_array, cv2.IMREAD_COLOR)
    # converting image from RGB to Grayscale
    gray = cv2.cvtColor(image_np, cv2.COLOR_BGR2GRAY)
    return gray

gray_imgs = list(map(convert_to_gray, keys))

# %%
plt.imshow(gray_imgs[0], 'gray')

# %%
def write_to_s3(img, key):
    from PIL import Image
    import io
    img = Image.fromarray(img).convert('RGB')
    out_img = io.BytesIO()
    img.save(out_img, format='png')
    out_img.seek(0)  
    return s3.Bucket('bcbs-logo-training-images').put_object(Key=key,Body=out_img,ContentType='image/png') 

def replace_keyname(key):
    return key.replace('raw_images', 'gray_images')

gray_keys = list(map(replace_keyname, keys))

print("Gray image keys: {}".format(len(gray_keys)))
print("Gray images: {}".format(len(gray_imgs)))
# Out:
# Gray image keys: 389
# Gray images: 389

# %%
[write_to_s3(x, y) for x, y in zip(gray_imgs, gray_keys)]
# Out:
# [s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/002.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/090315_BCBSopening51.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/10-10_bcbs-kansas-solutions-inc-id-card-samples.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/100-1024x536.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/102726425-64427_10151606029368653_471083024_n.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/10899709-34f0-4965-b9bf-af0bcfe72ccb-Letter.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/10ee1092b0d8c92e708082487a6d2242.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/11-04_Waterview_blog.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1149400efad9b15e962f01cb586f5fe3_-united-states-new-york-erie-county-orchard-park-north-buffalo-street-4086-bluecross-blueshield-of-wny-medicare-help-center-833-235-4049.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1200x630wa.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/125-1253024_blue-cross-blue-shield-of-florida-logo-png.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/130919 bluecross09.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1423142394_13095461_ver1.0_640_480.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1483469041601.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1483469048627.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1508466044_051563-c-bluecross_t1000_h8cd8aeb1fd738f949eb03991b89a8be377080d56.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1510606918777.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/180417dransomville_01.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/18f08ed90ca00289b5c10b5eb668bbb9.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/19095371226_b182b54f54_k-670x377.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/1941.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2010-10-21_Boeing_cardsample1_full.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2011122-blunite-experience-jefferson-exterior-night-view-1-12-05-111.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2015-02-10-bcbswnys-packaging.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2018 KMM BCBSAL-5149.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2018-12-13-BCBS-logo.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2019.10.10_art_truck_press_event_046.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/2170.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/22c02097e4438bd2f2f3fe4a6a3ab0e1_XL.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/268-2687205_blue-cross-blue-shield-png-blue-cross-blue.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/3.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/300x0w.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/300x0w.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/307-3074368_mj14-bluecross-blueshield-logotransparent-bg-blue-cross-blue.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/30841345_155628491942740_6261060692539867136_n.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/3616568037.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/43p1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/45718418_1204363043044914_3318312615020593152_n.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/478987-Large-fullheightview-from-the-southeast.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/49p1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/5-0.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/51p1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images
jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/bluecrossblueshield.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/c039c7501c0ced76f7f4fb5e849f8218.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/card_hs.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/cards1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/cards2.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/carefirst-breach-showcase_image-10-a-8248.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/carefirst-congress-id-card.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/carefirst_500.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/checkmark2.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/chicago-blue-cross-chicago-south-resized.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/dental-blue-insurance-cards.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/dental-card.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/direct-idcard-sample2.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/donation.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/download.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/download.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/eob-thumbnail.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/ex-live-fearless-reverse-lockup-larger.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/excellus-bluecross-blueshield-hacked-showcase_image-6-a-8527.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/fepblue_card_large.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/file.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/front-anthem.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/g14-737891.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/gettyimages-802088056-612x612.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/googlemic_color_24dp.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/grandopening.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/healthnow-930x590.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/hqdefault (1).jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/hqdefault.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/hscs_bridging_gaps-578b6761-1932-43cd-9d1b-0d2ce085cfcb-1508621211.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/https3A2F2Fi.forbesimg.com2Fmedia2Flists2Fcompanies2Fblue-cross-blue-shield-of-arkansas_416x416.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/https3A2F2Fspecials-images.forbesimg.com2Fimageserve2Fa8d04becc0594d4d99633675c26fa73c2F640x0.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/il_570xN.1017555822_8we1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/il_570xN.1017555878_fovx.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/il_794xN.1325550318_4v5d.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image0.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image003.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image1.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image10.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image11.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image12.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image13.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image15.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image17.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image19.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image2.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image20.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image21.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image22.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image23.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image26.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image27.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image29.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image31.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image32.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image33.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image34.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image35.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image36.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image37.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image38.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image39.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image4.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image40.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image41.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image42.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image43.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image44.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image5.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image6.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image7.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image8.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/image9.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images (1).jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images (2).jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images0.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images10.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images11.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images12.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images13.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images14.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images15.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images16.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images17.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images18.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images19.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images2.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images20.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images21.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images22.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images23.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images24.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images25.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images26.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images27.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images28.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images29.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images3.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images30.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images31.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images32.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images33.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images34.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images35.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images36.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images37.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images38.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images39.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images4.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images40.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images41.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images42.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images43.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images44.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images45.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images46.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images47.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images48.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images49.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images5.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images50.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images51.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images52.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images53.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images54.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images55.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images56.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images57.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images58.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images59.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images6.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images60.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images61.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images62.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images63.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images64.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images65.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images66.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images67.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images7.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images8.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/images9.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/imgbin-blue-cross-blue-shield-association-blue-cross-blue-shield-of-massachusetts-health-care-bluecross-blueshield-of-tennessee-blue-cross-and-blue-shield-of-minnesota-cQHCXeAiQUhegQxsCaWviFG7Z.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/kissclipart-bcbs-south-carolina-logo-clipart-bluecross-blueshi-5f0faabb0310db76.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/kissclipart-blue-cross-blue-shield-icon-clipart-blue-cross-blu-cca818867bfb5d37.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/l.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/l0.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/large_images.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/livefearless.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/logo-blue-cross-blue-shield-of-michigan-trademark-blue-cross-blue-shield-association-do-not-cross.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/logo-healthyplaces.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/logo.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/member-id-card-1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/my-brother-s-keeper-job-fair-2018.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/ok-bringing-information-and-access-to-tribal-communities-bcbs-article.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/photo.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/photo0.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/photo1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/photo_camera_grey600_24dp.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/prior-approval-non-formulary-medication-request-form-blue-cross-blue-shield-western-new-york-new-york_big.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/pw_e239115.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/rBVaSVvHIeSADJxYAABZD-iWEzQ797.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/slide_1.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/slide_2.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/snmmilogo.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/solution_spotlight_blue_cross_blue_shield_of_kansas_city.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/the-vision-and-the-promise.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/thumb.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/twitter_32x32.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/v1_99b885bf.png'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/vlVsyweSdYtCZsp-800x450-noPad.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/wellness-october.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/wny-live-fearless-hero.jpg'),
#  s3.Object(bucket_name='bcbs-logo-training-images', key='gray_images/zipari-logo-full-NEW.jpg')]
